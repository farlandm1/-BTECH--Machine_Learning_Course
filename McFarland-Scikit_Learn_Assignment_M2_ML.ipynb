# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv('Iris.csv')

# Assuming 'target_column_name' is the name of the column containing the target variable
#target_names = df['target_column_name'].unique()

#print("Target Names:")
#for name in target_names:
    #print(name)


print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
